# %% [markdown]
# # matplotlib - 2

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fig=figure() # Create a Figure instance
ax1=fig.add_axes([0., 0.38, 0.7, 0.3]) # Use the Figure instance to create one or more Axes or Subplot instances
ax2=fig.add_axes([0., 0., 0.7, 0.3])
ax1.plot(range(10),2*arange(10),"or") # Use the Axes instance helper methods to create the primitives
ax2.plot(range(10),range(10))
ax1.set_xlabel("x1")
ax2.set_xlabel("x2")
ax1.set_ylabel("y1")
ax2.set_ylabel("y2")
show(fig)
print ax1.lines
print type(ax1)
print ax2.lines
# Out:
# [<matplotlib.lines.Line2D object at 0x10b619150>]
# <class 'matplotlib.axes._axes.Axes'>
# [<matplotlib.lines.Line2D object at 0x10d059710>]

# %%
fig=figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(range(10))
print "getp(fig.patch)"
getp(fig.patch) # This prints the Artist's properties
print "getp(ax.patch)"
getp(ax.patch)
show(fig)
# Out:
# getp(fig.patch)
#     aa = False
#     agg_filter = None
#     alpha = None
#     animated = False
#     antialiased or aa = False
#     axes = None
#     bbox = Bbox('array([[ 0.,  0.],\n       [ 1.,  1.]])')
#     capstyle = butt
#     children = []
#     clip_box = None
#     clip_on = True
#     clip_path = None
#     contains = None
#     data_transform = BboxTransformTo(TransformedBbox(Bbox('array([[  0....
#     ec = (1, 1, 1, 0)
#     edgecolor or ec = (1, 1, 1, 0)
#     extents = Bbox('array([[    0.,     0.],\n       [ 1280.,   ...
#     facecolor or fc = (1, 1, 1, 0)
#     fc = (1, 1, 1, 0)
#     figure = Figure(1280x640)
#     fill = True
#     gid = None
#     hatch = None
#     height = 1
#     joinstyle = miter
#     label =
#     linestyle or ls = solid
#     linewidth or lw = 0.0
#     ls = solid
#     lw = 0.0
#     patch_transform = CompositeGenericTransform(BboxTransformTo(Bbox('ar...
#     path = Path(array([[ 0.,  0.],        [ 1.,  0.],        ...
#     path_effects = []
#     picker = None
#     rasterized = None
#     sketch_params = None
#     snap = None
#     transform = CompositeGenericTransform(CompositeGenericTransfor...
#     transformed_clip_path_and_affine = (None, None)
#     url = None
#     verts = [[    0.     0.]  [ 1280.     0.]  [ 1280.   640.]...
#     visible = True
#     width = 1
#     window_extent = Bbox('array([[    0.,     0.],\n       [ 1280.,   ...
#     x = 0
#     xy = (0, 0)
#     y = 0
#     zorder = 1
# getp(ax.patch)
#     aa = True
#     agg_filter = None
#     alpha = None
#     animated = False
#     antialiased or aa = True
#     axes = None
#     bbox = Bbox('array([[ 0.,  0.],\n       [ 1.,  1.]])')
#     capstyle = butt
#     children = []
#     clip_box = None
#     clip_on = True
#     clip_path = None
#     contains = None
#     data_transform = BboxTransformTo(TransformedBbox(Bbox('array([[ 0.,...
#     ec = (0.0, 0.0, 0.0, 0.0)
#     edgecolor or ec = (0.0, 0.0, 0.0, 0.0)
#     extents = Bbox('array([[    0.,     0.],\n       [ 1280.,   ...
#     facecolor or fc = (1.0, 1.0, 1.0, 1.0)
#     fc = (1.0, 1.0, 1.0, 1.0)
#     figure = Figure(1280x640)
#     fill = True
#     gid = None
#     hatch = None
#     height = 1.0
#     joinstyle = miter
#     label =
#     linestyle or ls = solid
#     linewidth or lw = 0
#     ls = solid
#     lw = 0
#     patch_transform = CompositeGenericTransform(BboxTransformTo(Bbox('ar...
#     path = Path(array([[ 0.,  0.],        [ 1.,  0.],        ...
#     path_effects = []
#     picker = None
#     rasterized = None
#     sketch_params = None
#     snap = None
#     transform = CompositeGenericTransform(CompositeGenericTransfor...
#     transformed_clip_path_and_affine = (None, None)
#     url = None
#     verts = [[    0.     0.]  [ 1280.     0.]  [ 1280.   640.]...
#     visible = True
#     width = 1.0
#     window_extent = Bbox('array([[    0.,     0.],\n       [ 1280.,   ...
#     x = 0.0
#     xy = (0.0, 0.0)
#     y = 0.0
#     zorder = 1

# %%
fig=figure()
ax1=fig.add_subplot(1,2,1)
ax2=fig.add_subplot(1,2,2)
for ax in fig.axes:
    ax.grid(False)

# %%
fig=figure()
ax=fig.add_subplot(111)
rect=ax.patch
getp(rect)
rect.set_facecolor('blue')
getp(rect)
# Out:
#     aa = True
#     agg_filter = None
#     alpha = None
#     animated = False
#     antialiased or aa = True
#     axes = None
#     bbox = Bbox('array([[ 0.,  0.],\n       [ 1.,  1.]])')
#     capstyle = butt
#     children = []
#     clip_box = None
#     clip_on = True
#     clip_path = None
#     contains = None
#     data_transform = BboxTransformTo(TransformedBbox(Bbox('array([[ 0.1...
#     ec = (0.0, 0.0, 0.0, 0.0)
#     edgecolor or ec = (0.0, 0.0, 0.0, 0.0)
#     extents = Bbox('array([[  160.,    80.],\n       [ 1152.,   ...
#     facecolor or fc = (1.0, 1.0, 1.0, 1.0)
#     fc = (1.0, 1.0, 1.0, 1.0)
#     figure = Figure(1280x640)
#     fill = True
#     gid = None
#     hatch = None
#     height = 1.0
#     joinstyle = miter
#     label =
#     linestyle or ls = solid
#     linewidth or lw = 0
#     ls = solid
#     lw = 0
#     patch_transform = CompositeGenericTransform(BboxTransformTo(Bbox('ar...
#     path = Path(array([[ 0.,  0.],        [ 1.,  0.],        ...
#     path_effects = []
#     picker = None
#     rasterized = None
#     sketch_params = None
#     snap = None
#     transform = CompositeGenericTransform(CompositeGenericTransfor...
#     transformed_clip_path_and_affine = (None, None)
#     url = None
#     verts = [[  160.    80.]  [ 1152.    80.]  [ 1152.   576.]...
#     visible = True
#     width = 1.0
#     window_extent = Bbox('array([[  160.,    80.],\n       [ 1152.,   ...
#     x = 0.0
#     xy = (0.0, 0.0)
#     y = 0.0
#     zorder = 1
#     aa = True
#     agg_filter = None
#     alpha = None
#     animated = False
#     antialiased or aa = True
#     axes = None
#     bbox = Bbox('array([[ 0.,  0.],\n       [ 1.,  1.]])')
#     capstyle = butt
#     children = []
#     clip_box = None
#     clip_on = True
#     clip_path = None
#     contains = None
#     data_transform = BboxTransformTo(TransformedBbox(Bbox('array([[ 0.1...
#     ec = (0.0, 0.0, 0.0, 0.0)
#     edgecolor or ec = (0.0, 0.0, 0.0, 0.0)
#     extents = Bbox('array([[  160.,    80.],\n       [ 1152.,   ...
#     facecolor or fc = (0.0, 0.0, 1.0, 1.0)
#     fc = (0.0, 0.0, 1.0, 1.0)
#     figure = Figure(1280x640)
#     fill = True
#     gid = None
#     hatch = None
#     height = 1.0
#     joinstyle = miter
#     label =
#     linestyle or ls = solid
#     linewidth or lw = 0
#     ls = solid
#     lw = 0
#     patch_transform = CompositeGenericTransform(BboxTransformTo(Bbox('ar...
#     path = Path(array([[ 0.,  0.],        [ 1.,  0.],        ...
#     path_effects = []
#     picker = None
#     rasterized = None
#     sketch_params = None
#     snap = None
#     transform = CompositeGenericTransform(CompositeGenericTransfor...
#     transformed_clip_path_and_affine = (None, None)
#     url = None
#     verts = [[  160.    80.]  [ 1152.    80.]  [ 1152.   576.]...
#     visible = True
#     width = 1.0
#     window_extent = Bbox('array([[  160.,    80.],\n       [ 1152.,   ...
#     x = 0.0
#     xy = (0.0, 0.0)
#     y = 0.0
#     zorder = 1

# %%
x, y = random.rand(2,100)
fig=figure()
ax=fig.add_subplot(111)
ax.plot(x,y)
print ax.lines
ax.plot(2*x,2*y)
print ax.lines
show()
# Out:
# [<matplotlib.lines.Line2D object at 0x108e8f050>]
# [<matplotlib.lines.Line2D object at 0x108e8f050>, <matplotlib.lines.Line2D object at 0x108e8f110>]
