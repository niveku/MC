# %%
# %pylab inline
Nt=2000
Nl=50
L=10. # Lado del cubo
tmin=0
tmax=.3
xmin=-L/2
xmax=L/2
ymin=-L/2
ymax=L/2
dt=(tmax-tmin)/Nt
dx=(xmax-xmin)/Nl
v=425. # m/s
r=v*dt/dx
xcoords=np.linspace(xmin,xmax,Nl)
ycoords=np.linspace(xmin,xmax,Nl)
xmesh,ymesh=np.meshgrid(xcoords,ycoords)
tcoords=np.linspace(tmin,tmax,Nt)
cara1=np.zeros((Nt,Nl,Nl))
cara1[0] = np.exp(-xmesh**2)*np.exp(-ymesh**2)
for i in range(2,Nt):
    pdrum=cara1[i-1]
    ppdrum=cara1[i-2]
    cara1[i]=2*(1.-2.*r**2)*pdrum-ppdrum+r**2*(np.roll(pdrum,1,axis=1)+np.roll(pdrum,-1,axis=1)+np.roll(pdrum,1,axis=0)+np.roll(pdrum,-1,axis=0))   
principal= np.zeros((Nt,4*Nl,3*Nl))
plt.figure(figsize=(5,5))
plt.imshow(cara1[-1],cmap='gist_heat')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %matplotlib gtk
from matplotlib import animation
fig=plt.figure(figsize=(10,10))
plt.hold(True)
plt.pcolor(xcoords,ycoords,phi[0],cmap='gist_heat',vmin=0.,vmax=1.)
plt.xlim(xmin+dx,xmax-dx)
plt.ylim(ymin+dy,ymax-dy)
def animate(i):
    plt.pcolor(xcoords,ycoords,phi[i],cmap='gist_heat',vmin=0.,vmax=1.)
    plt.xlim(xmin+dx,xmax-dx)
    plt.ylim(ymin+dy,ymax-dy)
animacion = animation.FuncAnimation(fig, animate, np.arange(1,len(phi)),interval=20, blit=False)
plt.show()
plt.hold(False)
